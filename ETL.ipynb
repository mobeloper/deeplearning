# %% [markdown]
# ETL Pipelines with Prefect
# ==========================
#
# [Prefect](https://github.com/PrefectHQ/prefect) is a platform for automating data workflows.  Data engineers and data scientists can build, test and deploy production pipelines without worrying about all of the ["negative engineering" aspects](https://medium.com/the-prefect-blog/positive-and-negative-data-engineering-a02cb497583d) of production.  For example, Prefect makes it easy to deploy a workflow that runs on a complicated schedule, requires task retries in the event of failures, and sends notifications when certain tasks are complete.  Prefect was built on top of Dask, and [relies on Dask](http://stories.dask.org/en/latest/prefect-workflows.html#how-dask-helps) to schedule and manage the execution of a Prefect workflow in a distributed environment.
#
# This example demonstrates running a Prefect ETL Flow on Dask which ultimately creates a GIF.  While this is a somewhat unconventional use case of Prefect, we're no strangers to [unconventional use cases](https://medium.com/the-prefect-blog/prefect-runs-on-prefect-3e6df553c3a4).
#
# In the world of workflow engines, Prefect supports many unique features; in this particular example we will see:
#
# - parametrization of workflows
# - dynamic runtime "mapping" of workflow tasks
# - customizable execution logic
#
# You wouldn't get this from any other engine.
#
# **Contents**
#
# 0. [Description of goal](#Goal)
# 1. Building our Flow
#     1. [Extract](#Extract)
#     1. [Transform](#Transform)
#     1. [Load](#Load)
#     1. [Putting the pieces together](#Build-the-Flow)
# 2. [Running our Flow on Dask](#Running-our-Flow-on-Dask)
# 3. [Watching our GIF](#Play)

# %% [markdown]
# [Goal](#Goal)
# ----
#
# To demonstrate how Prefect and Dask work together, we are going to build and execute a standard "Extract / Transform / Load" (ETL) workflow for processing some basic image data.  Most ETL workflows involve a scheduled migration of data from one database to another.  In our case, we will be moving data from a file located at a known URL to our local hard disk, converting the individual file into a series of frames, and compiling those frames into a GIF.  The URL references a file containing raw bytes such as:
#
# ```python
# b"""aÙw˜≠•∆≠≠ﬁ#!≠≠÷≠•Ω≠úΩ••µú•µîúµ•úΩ••Ω3&µ•Ω!
# µ≠∆≠•¥4(%µú∑≠≠Œ≠î≠≠≠∆≠îµúî≠úîµE5.≠ú≠≠•Œµµﬁ••∆•≠ŒµµŒúúΩ62&)1&623µ•∆Ωµ÷úî•ßjxΩΩÁú•Ωµ≠Œ••≠ú•≠Ω≠∆≠µÁâUV≠µ‹ΩµŒîî•NC5µ≠Ÿôãô•î•µ•µîú≠#VHCuhl≠≠ΩôchâRIoc]™≠Á≠î•™ú»öis•ú•f7,íYfL9?îî≠≠•÷∑ò™gWVxGEΩ≠–))1qB5µ≠Ω81R,´tÜñWV!HCDBB5;5?"""
# ```
#
# The steps of our workflow will be as follows:
#
# 1. Extract: pull the data file from a URL (specified by a `Parameter`) to disk
# 2. Transform: split the file into multiple files, each corresponding to a single frame
# 3. Load: Store each frame individually, and compile the frames together into a GIF
#
# Once we have built our Flow, we can execute it with different values for the `Parameter` or even run it on a nightly schedule.
#
# **NOTE:** If we planned on executing this Flow in a truly distributed environment, writing the images to the local filesystem would _not_ be appropriate.  We would instead use an external datastore such as Google Cloud Storage, or a proper database.

# %% [markdown]
# ### [Extract](#Extract)
#
# First, we will define our tasks for _extracting_ the image data file from a given URL and saving it to a given file location.  To do so, we will utilize two methods for creating Prefect Tasks:
# - the `task` decorator for converting any Python function into a task
# - a pre-written, configurable Task from the [Prefect "Task Library"](https://docs.prefect.io/guide/task_library/) which helps us abstract some standard boilerplate
#
# Additionally, we will utilize the following Prefect concepts:
# - a [Prefect signal](https://docs.prefect.io/guide/core_concepts/execution.html#state-signals) for marking this task and its downstream depedencies as successfully "Skipped" if the file is already present in our local filesystem
# - retry semantics: if, for whatever reason, our `curl` command fails to connect, we want it to retry up to 2 times with a 10 second delay.  This way, if we run this workflow on a schedule we won't need to concern ourselves with temporary intermittent connection issues.
#
# Right now we are simply defining our individual tasks - we won't actually set up our dependency structure until we create the full Flow.

# %%
# !pip install prefect
# Out:
# Collecting prefect
#   Downloading prefect-2.19.5-py3-none-any.whl.metadata (12 kB)
# Collecting aiosqlite>=0.17.0 (from prefect)
#   Downloading aiosqlite-0.20.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting alembic<2.0.0,>=1.7.5 (from prefect)
#   Downloading alembic-1.13.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting apprise<2.0.0,>=1.1.0 (from prefect)
#   Downloading apprise-1.8.0-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 564.1 kB/s eta 0:00:00a 0:00:01
# Collecting asyncpg>=0.23 (from prefect)
#   Downloading asyncpg-0.29.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (4.4 kB)
# Requirement already satisfied: click<8.2,>=8.0 in /opt/anaconda3/lib/python3.11/site-packages (from prefect) (8.1.7)
# Requirement already satisfied: cryptography>=36.0.1 in /opt/anaconda3/lib/python3.11/site-packages (from prefect) (42.0.2)
# Collecting dateparser<2.0.0,>=1.1.1 (from prefect)
#   Downloading dateparser-1.2.0-py2.py3-none-any.whl.metadata (28 kB)
# Collecting docker<7.0,>=4.0 (from prefect)
#   Downloading docker-6.1.3-py3-none-any.whl.metadata (3.5 kB)
# Collecting graphviz>=0.20.1 (from prefect)
#   Downloading graphviz-0.20.3-py3-none-any.whl.metadata (12 kB)
# Collecting griffe>=0.20.0 (from prefect)
#   Downloading griffe-0.47.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: jinja2<4.0.0,>=3.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from prefect) (3.1.3)
# Collecting jinja2-humanize-extension>=0.4.0 (from prefect)
#   Downloading jinja2_humanize_extension-0.4.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting humanize>=4.9.0 (from prefect)
#   Downloading humanize-4.9.0-py3-none-any.whl.metadata (7.9 kB)
# Collecting kubernetes<30.0.0,>=24.2.0 (from prefect)
#   Downloading kubernetes-29.0.0-py2.py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pytz<2025,>=2021.1 in /opt/anaconda3/lib/python3.11/site-packages (from prefect) (2023.3.post1)
# Collecting readchar<5.0.0,>=4.0.0 (from prefect)
#   Downloading readchar-4.1.0-py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: sqlalchemy!=1.4.33,<3.0.0,>=1.4.22 in /opt/anaconda3/lib/python3.11/site-packages (from sqlalchemy[asyncio]!=1.4.33,<3.0.0,>=1.4.22->prefect) (2.0.25)
# Collecting typer!=0.12.2,<0.13.0,>=0.12.0 (from prefect)
#   Downloading typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# Collecting anyio<4.0.0,>=3.7.1 (from prefect)
#   Using cached anyio-3.7.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting asgi-lifespan<3.0,>=1.0 (from prefect)
#   Downloading asgi_lifespan-2.1.0-py3-none-any.whl.metadata (10 kB)
# Collecting cachetools<6.0,>=5.3 (from prefect)
#   Using cached cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: cloudpickle<4.0,>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from prefect) (2.2.1)
# Collecting coolname<3.0.0,>=1.0.4 (from prefect)
#   Downloading coolname-2.2.0-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting croniter<3.0.0,>=1.0.12 (from prefect)
#   Downloading croniter-2.0.5-py2.py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: fsspec>=2022.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from prefect) (2023.10.0)
# Collecting httpcore<2.0.0,>=1.0.5 (from prefect)
#   Downloading httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# Collecting httpx!=0.23.2,>=0.23 (from httpx[http2]!=0.23.2,>=0.23->prefect)
#   Downloading httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting importlib-resources<6.2.0,>=6.1.3 (from prefect)
#   Downloading importlib_resources-6.1.3-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: jsonpatch<2.0,>=1.32 in /opt/anaconda3/lib/python3.11/site-packages (from prefect) (1.32)
# Requirement already satisfied: jsonschema<5.0.0,>=4.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from prefect) (4.19.2)
# Collecting orjson<4.0,>=3.7 (from prefect)
#   Downloading orjson-3.10.5-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl.metadata (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.7/49.7 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging<24.3,>=21.3 in /Users/oysterable/.local/lib/python3.11/site-packages (from prefect) (24.0)
# Requirement already satisfied: pathspec>=0.8.0 in /opt/anaconda3/lib/python3.11/site-packages (from prefect) (0.10.3)
# Requirement already satisfied: pydantic!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0 in /opt/anaconda3/lib/python3.11/site-packages (from pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->prefect) (1.10.12)
# Collecting pydantic-core<3.0.0,>=2.12.0 (from prefect)
#   Downloading pydantic_core-2.19.0-cp311-cp311-macosx_10_12_x86_64.whl.metadata (6.5 kB)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.2 in /Users/oysterable/.local/lib/python3.11/site-packages (from prefect) (2.9.0.post0)
# Requirement already satisfied: python-slugify<9.0,>=5.0 in /opt/anaconda3/lib/python3.11/site-packages (from prefect) (5.0.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from prefect) (6.0.1)
# Requirement already satisfied: rfc3339-validator<0.2.0,>=0.1.4 in /opt/anaconda3/lib/python3.11/site-packages (from prefect) (0.1.4)
# Requirement already satisfied: rich<14.0,>=11.0 in /opt/anaconda3/lib/python3.11/site-packages (from prefect) (13.3.5)
# Requirement already satisfied: ruamel.yaml>=0.17.0 in /opt/anaconda3/lib/python3.11/site-packages (from prefect) (0.17.21)
# Requirement already satisfied: sniffio<2.0.0,>=1.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from prefect) (1.3.0)
# Requirement already satisfied: toml>=0.10.0 in /opt/anaconda3/lib/python3.11/site-packages (from prefect) (0.10.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.5.0 in /Users/oysterable/.local/lib/python3.11/site-packages (from prefect) (4.11.0)
# Collecting ujson<6.0.0,>=5.8.0 (from prefect)
#   Downloading ujson-5.10.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (9.3 kB)
# Collecting uvicorn<0.29.0,>=0.14.0 (from prefect)
#   Downloading uvicorn-0.28.1-py3-none-any.whl.metadata (6.3 kB)
# Collecting websockets<13.0,>=10.4 (from prefect)
#   Downloading websockets-12.0-cp311-cp311-macosx_10_9_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: itsdangerous in /opt/anaconda3/lib/python3.11/site-packages (from prefect) (2.0.1)
# Collecting python-multipart>=0.0.7 (from prefect)
#   Downloading python_multipart-0.0.9-py3-none-any.whl.metadata (2.5 kB)
# Collecting pendulum<3.0 (from prefect)
#   Downloading pendulum-2.1.2.tar.gz (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 kB 2.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting Mako (from alembic<2.0.0,>=1.7.5->prefect)
#   Downloading Mako-1.3.5-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/lib/python3.11/site-packages (from anyio<4.0.0,>=3.7.1->prefect) (3.4)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.11/site-packages (from apprise<2.0.0,>=1.1.0->prefect) (2024.6.2)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (from apprise<2.0.0,>=1.1.0->prefect) (2.31.0)
# Collecting requests-oauthlib (from apprise<2.0.0,>=1.1.0->prefect)
#   Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: markdown in /opt/anaconda3/lib/python3.11/site-packages (from apprise<2.0.0,>=1.1.0->prefect) (3.4.1)
# Collecting async-timeout>=4.0.3 (from asyncpg>=0.23->prefect)
#   Using cached async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: cffi>=1.12 in /opt/anaconda3/lib/python3.11/site-packages (from cryptography>=36.0.1->prefect) (1.16.0)
# Requirement already satisfied: regex!=2019.02.19,!=2021.8.27 in /opt/anaconda3/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.1.1->prefect) (2023.10.3)
# Requirement already satisfied: tzlocal in /opt/anaconda3/lib/python3.11/site-packages (from dateparser<2.0.0,>=1.1.1->prefect) (2.1)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/anaconda3/lib/python3.11/site-packages (from docker<7.0,>=4.0->prefect) (2.0.7)
# Requirement already satisfied: websocket-client>=0.32.0 in /opt/anaconda3/lib/python3.11/site-packages (from docker<7.0,>=4.0->prefect) (0.58.0)
# Requirement already satisfied: colorama>=0.4 in /opt/anaconda3/lib/python3.11/site-packages (from griffe>=0.20.0->prefect) (0.4.6)
# Collecting h11<0.15,>=0.13 (from httpcore<2.0.0,>=1.0.5->prefect)
#   Downloading h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# Collecting h2<5,>=3 (from httpx[http2]!=0.23.2,>=0.23->prefect)
#   Downloading h2-4.1.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2<4.0.0,>=3.0.0->prefect) (2.1.3)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.32->prefect) (2.1)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->prefect) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->prefect) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->prefect) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.11/site-packages (from jsonschema<5.0.0,>=4.0.0->prefect) (0.10.6)
# Requirement already satisfied: six>=1.9.0 in /Users/oysterable/.local/lib/python3.11/site-packages (from kubernetes<30.0.0,>=24.2.0->prefect) (1.16.0)
# Collecting google-auth>=1.0.1 (from kubernetes<30.0.0,>=24.2.0->prefect)
#   Downloading google_auth-2.30.0-py2.py3-none-any.whl.metadata (4.7 kB)
# Collecting oauthlib>=3.2.2 (from kubernetes<30.0.0,>=24.2.0->prefect)
#   Using cached oauthlib-3.2.2-py3-none-any.whl.metadata (7.5 kB)
# Collecting pytzdata>=2020.1 (from pendulum<3.0->prefect)
#   Downloading pytzdata-2020.1-py2.py3-none-any.whl.metadata (2.3 kB)
# Collecting email-validator>=1.0.3 (from pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->prefect)
#   Downloading email_validator-2.2.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: text-unidecode>=1.3 in /opt/anaconda3/lib/python3.11/site-packages (from python-slugify<9.0,>=5.0->prefect) (1.3)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from rich<14.0,>=11.0->prefect) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/oysterable/.local/lib/python3.11/site-packages (from rich<14.0,>=11.0->prefect) (2.17.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from sqlalchemy!=1.4.33,<3.0.0,>=1.4.22->sqlalchemy[asyncio]!=1.4.33,<3.0.0,>=1.4.22->prefect) (3.0.1)
# Requirement already satisfied: shellingham>=1.3.0 in /opt/anaconda3/lib/python3.11/site-packages (from typer!=0.12.2,<0.13.0,>=0.12.0->prefect) (1.5.4)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.11/site-packages (from cffi>=1.12->cryptography>=36.0.1->prefect) (2.21)
# Collecting dnspython>=2.0.0 (from email-validator>=1.0.3->pydantic[email]!=2.0.0,!=2.0.1,!=2.1.0,<3.0.0,>=1.10.0->prefect)
#   Downloading dnspython-2.6.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/anaconda3/lib/python3.11/site-packages (from google-auth>=1.0.1->kubernetes<30.0.0,>=24.2.0->prefect) (0.2.8)
# Collecting rsa<5,>=3.1.4 (from google-auth>=1.0.1->kubernetes<30.0.0,>=24.2.0->prefect)
#   Using cached rsa-4.9-py3-none-any.whl.metadata (4.2 kB)
# Collecting hyperframe<7,>=6.0 (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect)
#   Downloading hyperframe-6.0.1-py3-none-any.whl.metadata (2.7 kB)
# Collecting hpack<5,>=4.0 (from h2<5,>=3->httpx[http2]!=0.23.2,>=0.23->prefect)
#   Downloading hpack-4.0.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: mdurl~=0.1 in /opt/anaconda3/lib/python3.11/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14.0,>=11.0->prefect) (0.1.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests->apprise<2.0.0,>=1.1.0->prefect) (2.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /opt/anaconda3/lib/python3.11/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes<30.0.0,>=24.2.0->prefect) (0.4.8)
# Downloading prefect-2.19.5-py3-none-any.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 7.0 MB/s eta 0:00:0000:0100:01
# Downloading aiosqlite-0.20.0-py3-none-any.whl (15 kB)
# Downloading alembic-1.13.1-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.4/233.4 kB 5.7 MB/s eta 0:00:00ta 0:00:01
# Using cached anyio-3.7.1-py3-none-any.whl (80 kB)
# Downloading apprise-1.8.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 7.9 MB/s eta 0:00:00ta 0:00:01
# Downloading asgi_lifespan-2.1.0-py3-none-any.whl (10 kB)
# Downloading asyncpg-0.29.0-cp311-cp311-macosx_10_9_x86_64.whl (653 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 653.1/653.1 kB 5.4 MB/s eta 0:00:00ta 0:00:01
# Using cached cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Downloading coolname-2.2.0-py2.py3-none-any.whl (37 kB)
# Downloading croniter-2.0.5-py2.py3-none-any.whl (20 kB)
# Downloading dateparser-1.2.0-py2.py3-none-any.whl (294 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 4.0 MB/s eta 0:00:00a 0:00:01
# Downloading docker-6.1.3-py3-none-any.whl (148 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.1/148.1 kB 3.1 MB/s eta 0:00:00ta 0:00:01
# Downloading graphviz-0.20.3-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.1/47.1 kB 573.1 kB/s eta 0:00:00 0:00:01
# Downloading griffe-0.47.0-py3-none-any.whl (122 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.2/122.2 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Downloading httpcore-1.0.5-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 2.3 MB/s eta 0:00:00
# Downloading httpx-0.27.0-py3-none-any.whl (75 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 2.5 MB/s eta 0:00:00
# Downloading humanize-4.9.0-py3-none-any.whl (126 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.8/126.8 kB 3.8 MB/s eta 0:00:00
# Downloading importlib_resources-6.1.3-py3-none-any.whl (34 kB)
# Downloading jinja2_humanize_extension-0.4.0-py3-none-any.whl (4.8 kB)
# Downloading kubernetes-29.0.0-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.4 MB/s eta 0:00:00a 0:00:01
# Downloading orjson-3.10.5-cp311-cp311-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (258 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 258.7/258.7 kB 1.0 MB/s eta 0:00:0000:0100:01
# Downloading pydantic_core-2.19.0-cp311-cp311-macosx_10_12_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 8.9 MB/s eta 0:00:00:00:010:01
# Downloading python_multipart-0.0.9-py3-none-any.whl (22 kB)
# Downloading readchar-4.1.0-py3-none-any.whl (9.1 kB)
# Downloading typer-0.12.3-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.2/47.2 kB 1.5 MB/s eta 0:00:00
# Downloading ujson-5.10.0-cp311-cp311-macosx_10_9_x86_64.whl (55 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/55.4 kB 1.3 MB/s eta 0:00:00a 0:00:01
# Downloading uvicorn-0.28.1-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.5/60.5 kB 191.2 kB/s eta 0:00:00a 0:00:01
# Downloading websockets-12.0-cp311-cp311-macosx_10_9_x86_64.whl (121 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 2.2 MB/s eta 0:00:00a 0:00:01
# Using cached async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading email_validator-2.2.0-py3-none-any.whl (33 kB)
# Downloading google_auth-2.30.0-py2.py3-none-any.whl (193 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.7/193.7 kB 2.1 MB/s eta 0:00:00a 0:00:01
# Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Downloading h2-4.1.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.5/57.5 kB 1.7 MB/s eta 0:00:00
# Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Downloading pytzdata-2020.1-py2.py3-none-any.whl (489 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 490.0/490.0 kB 3.5 MB/s eta 0:00:0000:0100:01
# Downloading Mako-1.3.5-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.6/78.6 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Using cached requests_oauthlib-2.0.0-py2.py3-none-any.whl (24 kB)
# Downloading dnspython-2.6.1-py3-none-any.whl (307 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.7/307.7 kB 3.6 MB/s eta 0:00:0000:010:01
# Downloading hpack-4.0.0-py3-none-any.whl (32 kB)
# Downloading hyperframe-6.0.1-py3-none-any.whl (12 kB)
# Using cached rsa-4.9-py3-none-any.whl (34 kB)
# Building wheels for collected packages: pendulum
#   Building wheel for pendulum (pyproject.toml) ... done
#   Created wheel for pendulum: filename=pendulum-2.1.2-cp311-cp311-macosx_13_0_x86_64.whl size=125087 sha256=b6e26cd5e5b4dd330f394e7479e9d64ae1ddf95b46c59c9bc62aa274ddaeddc0
#   Stored in directory: /Users/oysterable/Library/Caches/pip/wheels/a4/b7/10/a86f4f49b1bdf8a0cf3da42d48f499e4cb7529ebab7aad3550
# Successfully built pendulum
# Installing collected packages: coolname, websockets, ujson, rsa, readchar, pytzdata, python-multipart, pydantic-core, orjson, oauthlib, Mako, importlib-resources, hyperframe, humanize, hpack, h11, griffe, graphviz, dnspython, cachetools, async-timeout, asgi-lifespan, anyio, aiosqlite, uvicorn, requests-oauthlib, pendulum, jinja2-humanize-extension, httpcore, h2, google-auth, email-validator, docker, dateparser, croniter, asyncpg, alembic, typer, kubernetes, httpx, apprise, prefect
#   Attempting uninstall: ujson
#     Found existing installation: ujson 5.4.0
#     Uninstalling ujson-5.4.0:
#       Successfully uninstalled ujson-5.4.0
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 4.2.2
#     Uninstalling cachetools-4.2.2:
#       Successfully uninstalled cachetools-4.2.2
#   Attempting uninstall: anyio
#     Found existing installation: anyio 4.2.0
#     Uninstalling anyio-4.2.0:
#       Successfully uninstalled anyio-4.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# python-lsp-server 1.7.2 requires jedi<0.19.0,>=0.17.2, but you have jedi 0.19.1 which is incompatible.
# spyder 5.4.3 requires jedi<0.19.0,>=0.17.2, but you have jedi 0.19.1 which is incompatible.
# Successfully installed Mako-1.3.5 aiosqlite-0.20.0 alembic-1.13.1 anyio-3.7.1 apprise-1.8.0 asgi-lifespan-2.1.0 async-timeout-4.0.3 asyncpg-0.29.0 cachetools-5.3.3 coolname-2.2.0 croniter-2.0.5 dateparser-1.2.0 dnspython-2.6.1 docker-6.1.3 email-validator-2.2.0 google-auth-2.30.0 graphviz-0.20.3 griffe-0.47.0 h11-0.14.0 h2-4.1.0 hpack-4.0.0 httpcore-1.0.5 httpx-0.27.0 humanize-4.9.0 hyperframe-6.0.1 importlib-resources-6.1.3 jinja2-humanize-extension-0.4.0 kubernetes-29.0.0 oauthlib-3.2.2 orjson-3.10.5 pendulum-2.1.2 prefect-2.19.5 pydantic-core-2.19.0 python-multipart-0.0.9 pytzdata-2020.1 readchar-4.1.0 requests-oauthlib-2.0.0 rsa-4.9 typer-0.12.3 ujson-5.10.0 uvicorn-0.28.1 websockets-12.0

# %%
import datetime
import os

import prefect 
from prefect import task
from prefect.engine.signals import SKIP
from prefect.tasks.shell import ShellTask


@task
def curl_cmd(url: str, fname: str) -> str:
    """
    The curl command we wish to execute.
    """
    if os.path.exists(fname):
        raise SKIP("Image data file already exists.")
    return "curl -fL -o {fname} {url}".format(fname=fname, url=url)


# ShellTask is a task from the Task library which will execute a given command in a subprocess
# and fail if the command returns a non-zero exit code

download = ShellTask(name="curl_task", max_retries=2, retry_delay=datetime.timedelta(seconds=10))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       4 import prefect
#       5 from prefect import task
# ----> 6 from prefect.engine.signals import SKIP
#       7 from prefect.tasks.shell import ShellTask
#      10 @task
#      11 def curl_cmd(url: str, fname: str) -> str:
#
# ModuleNotFoundError: No module named 'prefect.engine.signals'; 'prefect.engine' is not a package

# %% [markdown]
# ### [Transform](#Transform)
#
# Next up, we need to define our task which loads the image data file and splits it into multiple frames.  In this case, each frame is delimited by 4 newlines.  Note that, in the event the previous two tasks are "Skipped", the default behavior in Prefect is to skip downstream dependencies as well.  However, as with most things in Prefect, this behavior is customizable.  In this case, we want this task to run regardless of whether the upstreams skipped or not, so we set the `skip_on_upstream_skip` flag to `False`.

# %%
@task(skip_on_upstream_skip=False)
def load_and_split(fname: str) -> list:
    """
    Loads image data file at `fname` and splits it into
    multiple frames.  Returns a list of bytes, one element
    for each frame.
    """
    with open(fname, "rb") as f:
        images = f.read()
        
    return [img for img in images.split(b"\n" * 4) if img]

# %% [markdown]
# ### [Load](#Load)
#
# Finally, we want to write our frames to disk as well as combine the frames into a single GIF.  In order to achieve this goal, we are going to utilize [Prefect's task "mapping" feature](https://docs.prefect.io/guide/core_concepts/mapping.html) which conveniently spawns new tasks in response to upstream outputs.  In this case, we will write a single task for writing an image to disk, and "map" this task over all the image frames returned by `load_and_split` above!  To infer which frame we are on, we look in [`prefect.context`](https://docs.prefect.io/guide/core_concepts/execution.html#context).
#
# Additionally, we can "reduce" over a mapped task - in this case, we will take the collection of mapped tasks and pass them into our `combine_to_gif` task for creating and saving our GIF.

# %%
@task
def write_to_disk(image: bytes) -> bytes:
    """
    Given a single image represented as bytes, writes the image
    to the present working directory with a filename determined
    by `map_index`.  Returns the image bytes.
    """
    frame_no = prefect.context.get("map_index")
    with open("frame_{0:0=2d}.gif".format(frame_no), "wb") as f:
        f.write(image)
    return image

# %%
import imageio
from io import BytesIO


@task
def combine_to_gif(image_bytes: list) -> None:
    """
    Given a list of ordered images represented as bytes,
    combines them into a single GIF stored in the present working directory.
    """
    images = [imageio.imread(BytesIO(image)) for image in image_bytes]
    imageio.mimsave('./clip.gif', images)

# %% [markdown]
# [Build the Flow](#Build-the-Flow)
# ---------------
#
# Finally, we need to put our tasks together into a Prefect "Flow".  Similar to Dask's `delayed` interface, all computation is deferred and no Task code will be executed in this step.  Because Prefect maintains a stricter contract between tasks and additionally needs the ability to run in non-Dask execution environments, the mechanism for deferring execution is independent of Dask.
#
# In addition to the tasks we have already defined, we introduce two "Parameters" for specifying the URL and local file location of our data.  At runtime, we can optionally override these tasks to return different values.

# %%
from prefect import Parameter, Flow


DATA_URL = Parameter("DATA_URL", 
                     default="https://github.com/cicdw/image-data/blob/master/all-images.img?raw=true")

DATA_FILE = Parameter("DATA_FILE", default="image-data.img")


with Flow("Image ETL") as flow:
    
    # Extract
    command = curl_cmd(DATA_URL, DATA_FILE)
    curl = download(command=command)
    
    # Transform
    # we use the `upstream_tasks` keyword to specify non-data dependencies
    images = load_and_split(fname=DATA_FILE, upstream_tasks=[curl])
    
    # Load  
    frames = write_to_disk.map(images)
    result = combine_to_gif(frames)
    

flow.visualize()

# %% [markdown]
# ### [Running the Flow on Dask](#Running-the-Flow-on-Dask)
#
# Now we have built our Flow, independently of Dask.  We could execute this Flow sequentially, Task after Task, but there is inherent parallelism in our mapping of the images to files that we want to exploit.  Luckily, Dask makes this easy to achieve.
#
# First, we will start a local Dask cluster.  Then, we will run our Flow against Prefect's `DaskExecutor`, which will submit each Task to our Dask cluster and use Dask's distributed scheduler for determining when and where each Task should run.  Essentially, we built a Directed Acylic Graph (DAG) and are simply "submitting" that DAG to Dask for handling its execution in a distributed way.

# %%
# start our Dask cluster
from dask.distributed import Client


client = Client(n_workers=4, threads_per_worker=1)

# point Prefect's DaskExecutor to our Dask cluster

from prefect.executors import DaskExecutor

executor = DaskExecutor(address=client.scheduler.address)
flow.run(executor=executor)

# %% [markdown]
# [Next Steps](#Next-Steps)
# ----------
#
# Now that we've built our workflow, what next?  The interested reader should try to:
#
# - run the Flow again to see how the `SKIP` signal behaves
# - use different parameters for both the URL and the file location (Parameter values can be overriden by simply passing their names as keyword arguments to `flow.run()`)
# - introduce a new Parameter for the filename of the final GIF
# - use Prefect's [scheduler interface](https://docs.prefect.io/guide/core_concepts/schedules.html) to run our workflow on a schedule

# %% [markdown]
# [Play](#Play)
# ----
#
# Finally, let's watch our creation!

# %%
from IPython.display import Image

Image(filename="clip.gif", alt="Rick Daskley")
