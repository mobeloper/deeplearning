# %%
## Tutorial on Early Stopping

# %% [markdown]
# Early stopping is a feature :
# - that enables the training to be automatically stopped when a chosen metric has stopped improving.
# -  form of regularization used to avoid overfitting.
# - Use early stopping if you don’t want to train your model for too long.

# %%
### Importing the necessary packages

import pandas as pd
import io
import requests
import numpy as np
from sklearn import metrics
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras.callbacks import EarlyStopping

# %%
## dataset_link : "https://data.heatonresearch.com/data/t81-558/iris.csv",

# %%
### Reading Iris data set
df = pd.read_csv(
    "https://data.heatonresearch.com/data/t81-558/iris.csv", 
    na_values=['NA', '?'])

# %%
df.head(5)
# Out:
#    sepal_l  sepal_w  petal_l  petal_w      species
# 0      5.1      3.5      1.4      0.2  Iris-setosa
# 1      4.9      3.0      1.4      0.2  Iris-setosa
# 2      4.7      3.2      1.3      0.2  Iris-setosa
# 3      4.6      3.1      1.5      0.2  Iris-setosa
# 4      5.0      3.6      1.4      0.2  Iris-setosa

# %%
df.tail(5)
# Out:
#      sepal_l  sepal_w  petal_l  petal_w         species
# 145      6.7      3.0      5.2      2.3  Iris-virginica
# 146      6.3      2.5      5.0      1.9  Iris-virginica
# 147      6.5      3.0      5.2      2.0  Iris-virginica
# 148      6.2      3.4      5.4      2.3  Iris-virginica
# 149      5.9      3.0      5.1      1.8  Iris-virginica

# %%
# Convert to numpy - Classification


# Convert to numpy - Classification
x = df[['sepal_l', 'sepal_w', 'petal_l', 'petal_w']].values
dummies = pd.get_dummies(df['species']) # Classification
species = dummies.columns
y = dummies.values

# %%
# Split into validation and training sets

x_train, x_test, y_train, y_test = train_test_split(    
    x, y, test_size=0.25, random_state=42)

# %%
# Build neural network

model = Sequential()
model.add(Dense(50, input_dim=x.shape[1], activation='relu')) # Hidden 1
model.add(Dense(25, activation='relu')) # Hidden 2
model.add(Dense(y.shape[1],activation='softmax')) # Output
model.compile(loss='categorical_crossentropy', optimizer='adam')

# %% [markdown]
# There are a number of parameters that are specified to the EarlyStopping object.
#
# - min_delta This value should be kept small. It simply means the minimum change in error to be registered as an improvement. Setting it even smaller will not likely have a great deal of impact.
# - patience : This is the number of epochs without improvement after which training will be early stopped.
#   A larger patience means that an experiment will wait longer before stopping an experiment.
# - verbose How much progress information do you want?
# - mode In general, always set this to "auto".
# - restore_best_weights This should always be set to true. T
#
# # How it works
# Early stopping monitors the evolution of the given metric after every epoch. If the metric has not improved for Patience epochs in a row, the experiment is early stopped.
# Select run until validation loss stops improving and use early stopping to make a stopping decision.

# %%
monitor = EarlyStopping(monitor='val_loss', min_delta=1e-3, patience=5, 
        verbose=1, mode='auto', restore_best_weights=True)
model.fit(x_train,y_train,validation_data=(x_test,y_test),
        callbacks=[monitor],verbose=2,epochs=1000)

# we are running this model for 1000 epochs
# Out:
# Epoch 1/1000
# 4/4 - 1s - loss: 1.8197 - val_loss: 1.6354 - 548ms/epoch - 137ms/step
# Epoch 2/1000
# 4/4 - 0s - loss: 1.5316 - val_loss: 1.3836 - 24ms/epoch - 6ms/step
# Epoch 3/1000
# 4/4 - 0s - loss: 1.3252 - val_loss: 1.2132 - 34ms/epoch - 8ms/step
# Epoch 4/1000
# 4/4 - 0s - loss: 1.1857 - val_loss: 1.0948 - 26ms/epoch - 6ms/step
# Epoch 5/1000
# 4/4 - 0s - loss: 1.0727 - val_loss: 1.0042 - 24ms/epoch - 6ms/step
# Epoch 6/1000
# 4/4 - 0s - loss: 0.9916 - val_loss: 0.9342 - 27ms/epoch - 7ms/step
# Epoch 7/1000
# 4/4 - 0s - loss: 0.9301 - val_loss: 0.8846 - 35ms/epoch - 9ms/step
# Epoch 8/1000
# 4/4 - 0s - loss: 0.8851 - val_loss: 0.8410 - 33ms/epoch - 8ms/step
# Epoch 9/1000
# 4/4 - 0s - loss: 0.8468 - val_loss: 0.8043 - 28ms/epoch - 7ms/step
# Epoch 10/1000
# 4/4 - 0s - loss: 0.8103 - val_loss: 0.7637 - 29ms/epoch - 7ms/step
# Epoch 11/1000
# 4/4 - 0s - loss: 0.7774 - val_loss: 0.7300 - 24ms/epoch - 6ms/step
# Epoch 12/1000
# 4/4 - 0s - loss: 0.7503 - val_loss: 0.7007 - 23ms/epoch - 6ms/step
# Epoch 13/1000
# 4/4 - 0s - loss: 0.7244 - val_loss: 0.6753 - 28ms/epoch - 7ms/step
# Epoch 14/1000
# 4/4 - 0s - loss: 0.7004 - val_loss: 0.6512 - 26ms/epoch - 7ms/step
# Epoch 15/1000
# 4/4 - 0s - loss: 0.6775 - val_loss: 0.6274 - 24ms/epoch - 6ms/step
# Epoch 16/1000
# 4/4 - 0s - loss: 0.6556 - val_loss: 0.6044 - 31ms/epoch - 8ms/step
# Epoch 17/1000
# 4/4 - 0s - loss: 0.6349 - val_loss: 0.5821 - 26ms/epoch - 7ms/step
# Epoch 18/1000
# 4/4 - 0s - loss: 0.6154 - val_loss: 0.5611 - 27ms/epoch - 7ms/step
# Epoch 19/1000
# 4/4 - 0s - loss: 0.5947 - val_loss: 0.5415 - 27ms/epoch - 7ms/step
# Epoch 20/1000
# 4/4 - 0s - loss: 0.5755 - val_loss: 0.5231 - 28ms/epoch - 7ms/step
# Epoch 21/1000
# 4/4 - 0s - loss: 0.5570 - val_loss: 0.5047 - 51ms/epoch - 13ms/step
# Epoch 22/1000
# 4/4 - 0s - loss: 0.5415 - val_loss: 0.4874 - 27ms/epoch - 7ms/step
# Epoch 23/1000
# 4/4 - 0s - loss: 0.5285 - val_loss: 0.4720 - 34ms/epoch - 8ms/step
# Epoch 24/1000
# 4/4 - 0s - loss: 0.5073 - val_loss: 0.4525 - 33ms/epoch - 8ms/step
# Epoch 25/1000
# 4/4 - 0s - loss: 0.4924 - val_loss: 0.4456 - 33ms/epoch - 8ms/step
# Epoch 26/1000
# 4/4 - 0s - loss:
ms/step
# Epoch 78/1000
# 4/4 - 0s - loss: 0.1632 - val_loss: 0.1383 - 24ms/epoch - 6ms/step
# Epoch 79/1000
# 4/4 - 0s - loss: 0.1604 - val_loss: 0.1374 - 25ms/epoch - 6ms/step
# Epoch 80/1000
# 4/4 - 0s - loss: 0.1582 - val_loss: 0.1334 - 25ms/epoch - 6ms/step
# Epoch 81/1000
# 4/4 - 0s - loss: 0.1554 - val_loss: 0.1320 - 25ms/epoch - 6ms/step
# Epoch 82/1000
# 4/4 - 0s - loss: 0.1533 - val_loss: 0.1333 - 29ms/epoch - 7ms/step
# Epoch 83/1000
# 4/4 - 0s - loss: 0.1522 - val_loss: 0.1292 - 25ms/epoch - 6ms/step
# Epoch 84/1000
# 4/4 - 0s - loss: 0.1486 - val_loss: 0.1278 - 23ms/epoch - 6ms/step
# Epoch 85/1000
# 4/4 - 0s - loss: 0.1464 - val_loss: 0.1256 - 24ms/epoch - 6ms/step
# Epoch 86/1000
# 4/4 - 0s - loss: 0.1447 - val_loss: 0.1227 - 25ms/epoch - 6ms/step
# Epoch 87/1000
# 4/4 - 0s - loss: 0.1434 - val_loss: 0.1203 - 23ms/epoch - 6ms/step
# Epoch 88/1000
# 4/4 - 0s - loss: 0.1408 - val_loss: 0.1203 - 27ms/epoch - 7ms/step
# Epoch 89/1000
# 4/4 - 0s - loss: 0.1395 - val_loss: 0.1248 - 23ms/epoch - 6ms/step
# Epoch 90/1000
# 4/4 - 0s - loss: 0.1397 - val_loss: 0.1227 - 30ms/epoch - 7ms/step
# Epoch 91/1000
# 4/4 - 0s - loss: 0.1370 - val_loss: 0.1141 - 25ms/epoch - 6ms/step
# Epoch 92/1000
# 4/4 - 0s - loss: 0.1367 - val_loss: 0.1122 - 25ms/epoch - 6ms/step
# Epoch 93/1000
# 4/4 - 0s - loss: 0.1351 - val_loss: 0.1170 - 25ms/epoch - 6ms/step
# Epoch 94/1000
# 4/4 - 0s - loss: 0.1317 - val_loss: 0.1140 - 22ms/epoch - 6ms/step
# Epoch 95/1000
# 4/4 - 0s - loss: 0.1296 - val_loss: 0.1114 - 23ms/epoch - 6ms/step
# Epoch 96/1000
# 4/4 - 0s - loss: 0.1271 - val_loss: 0.1073 - 27ms/epoch - 7ms/step
# Epoch 97/1000
# 4/4 - 0s - loss: 0.1289 - val_loss: 0.1058 - 24ms/epoch - 6ms/step
# Epoch 98/1000
# 4/4 - 0s - loss: 0.1247 - val_loss: 0.1104 - 24ms/epoch - 6ms/step
# Epoch 99/1000
# 4/4 - 0s - loss: 0.1273 - val_loss: 0.1143 - 32ms/epoch - 8ms/step
# Epoch 100/1000
# 4/4 - 0s - loss: 0.1250 - val_loss: 0.1055 - 30ms/epoch - 8ms/step
# Epoch 101/1000
# 4/4 - 0s - loss: 0.1218 - val_loss: 0.1015 - 31ms/epoch - 8ms/step
# Epoch 102/1000
# 4/4 - 0s - loss: 0.1232 - val_loss: 0.1001 - 25ms/epoch - 6ms/step
# Epoch 103/1000
# 4/4 - 0s - loss: 0.1180 - val_loss: 0.1076 - 23ms/epoch - 6ms/step
# Epoch 104/1000
# 4/4 - 0s - loss: 0.1210 - val_loss: 0.1096 - 42ms/epoch - 10ms/step
# Epoch 105/1000
# 4/4 - 0s - loss: 0.1174 - val_loss: 0.0990 - 30ms/epoch - 7ms/step
# Epoch 106/1000
# 4/4 - 0s - loss: 0.1149 - val_loss: 0.0958 - 25ms/epoch - 6ms/step
# Epoch 107/1000
# 4/4 - 0s - loss: 0.1159 - val_loss: 0.0955 - 24ms/epoch - 6ms/step
# Epoch 108/1000
# 4/4 - 0s - loss: 0.1126 - val_loss: 0.1018 - 23ms/epoch - 6ms/step
# Epoch 109/1000
# 4/4 - 0s - loss: 0.1148 - val_loss: 0.1015 - 25ms/epoch - 6ms/step
# Epoch 110/1000
# 4/4 - 0s - loss: 0.1122 - val_loss: 0.0982 - 27ms/epoch - 7ms/step
# Epoch 111/1000
# 4/4 - 0s - loss: 0.1092 - val_loss: 0.0924 - 27ms/epoch - 7ms/step
# Epoch 112/1000
# 4/4 - 0s - loss: 0.1103 - val_loss: 0.0904 - 25ms/epoch - 6ms/step
# Epoch 113/1000
# 4/4 - 0s - loss: 0.1106 - val_loss: 0.0906 - 31ms/epoch - 8ms/step
# Epoch 114/1000
# 4/4 - 0s - loss: 0.1078 - val_loss: 0.0914 - 43ms/epoch - 11ms/step
# Epoch 115/1000
# 4/4 - 0s - loss: 0.1060 - val_loss: 0.0946 - 24ms/epoch - 6ms/step
# Epoch 116/1000
# 4/4 - 0s - loss: 0.1086 - val_loss: 0.0977 - 22ms/epoch - 6ms/step
# Epoch 117/1000
# Restoring model weights from the end of the best epoch: 112.
# 4/4 - 0s - loss: 0.1061 - val_loss: 0.0903 - 26ms/epoch - 7ms/step
# Epoch 117: early stopping

# %%
# Drwabacks of early stopping:

- A problem with early stopping is that the model does not make use of all available training data. 
- It may be desirable to avoid overfitting and to train on all possible data, especially on problems where the amount of training data is very limited.
